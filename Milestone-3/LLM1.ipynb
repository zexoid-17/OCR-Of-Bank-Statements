# %%
# !pip install paddlepaddle
# !pip install paddleocr
# !pip install cohere
# !pip install gradio
# !pip install opencv-python-headless
# !pip install matplotlib
# !pip install pandas
# Out:
# Requirement already satisfied: paddlepaddle in c:\users\delll\anaconda3\lib\site-packages (2.6.2)
# Requirement already satisfied: httpx in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (0.27.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (11.0.0)
# Requirement already satisfied: decorator in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: astor in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf<=3.20.2,>=3.1.0 in c:\users\delll\anaconda3\lib\site-packages (from paddlepaddle) (3.20.2)
# Requirement already satisfied: anyio in c:\users\delll\anaconda3\lib\site-packages (from httpx->paddlepaddle) (4.2.0)
# Requirement already satisfied: certifi in c:\users\delll\anaconda3\lib\site-packages (from httpx->paddlepaddle) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\delll\anaconda3\lib\site-packages (from httpx->paddlepaddle) (1.0.5)
# Requirement already satisfied: idna in c:\users\delll\anaconda3\lib\site-packages (from httpx->paddlepaddle) (3.10)
# Requirement already satisfied: sniffio in c:\users\delll\anaconda3\lib\site-packages (from httpx->paddlepaddle) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\delll\anaconda3\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: paddleocr in c:\users\delll\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: shapely in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (0.22.0)
# Requirement already satisfied: imgaug in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (1.3.0.post6)
# Requirement already satisfied: lmdb in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (1.4.1)
# Requirement already satisfied: tqdm in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (4.65.0)
# Requirement already satisfied: numpy<2.0 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (3.10.1)
# Requirement already satisfied: opencv-python in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: Pillow in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (11.0.0)
# Requirement already satisfied: pyyaml in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (6.0.1)
# Requirement already satisfied: python-docx in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (4.12.2)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (4.25.0)
# Requirement already satisfied: fire>=0.3.0 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (0.7.0)
# Requirement already satisfied: requests in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: albumentations==1.4.10 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (1.4.10)
# Requirement already satisfied: albucore==0.0.13 in c:\users\delll\anaconda3\lib\site-packages (from paddleocr) (0.0.13)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\delll\anaconda3\lib\site-packages (from albucore==0.0.13->paddleocr) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\delll\anaconda3\lib\site-packages (from albucore==0.0.13->paddleocr) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\delll\anaconda3\lib\site-packages (from albucore==0.0.13->paddleocr) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\delll\anaconda3\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\delll\anaconda3\lib\site-packages (from albumentations==1.4.10->paddleocr) (1.5.2)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\delll\anaconda3\lib\site-packages (from albumentations==1.4.10->paddleocr) (2.10.2)
# Requirement already satisfied: termcolor in c:\users\delll\anaconda3\lib\site-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\delll\anaconda3\lib\site-packages (from scikit-image->paddleocr) (3.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\delll\anaconda3\lib\site-packages (from scikit-image->paddleocr) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\delll\anaconda3\lib\site-packages (from scikit-image->paddleocr) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\delll\anaconda3\lib\site-packages (from scikit-image->paddleocr) (24.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\delll\anaconda3\lib\site-packages (from scikit-image->paddleocr) (0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\delll\anaconda3\lib\site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: six in c:\users\delll\anaconda3\lib\site-packages (from imgaug->paddleocr) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\delll\anaconda3\lib\site-packages (from imgaug->paddleocr) (3.8.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\delll\anaconda3\lib\site-packages (from python-docx->paddleocr) (4.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\delll\anaconda3\lib\site-packages (from requests->paddleocr) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\delll\anaconda3\lib\site-packages (from requests->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\delll\anaconda3\lib\site-packages (from requests->paddleocr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\delll\anaconda3\lib\site-packages (from requests->paddleocr) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\delll\anaconda3\lib\site-packages (from tqdm->paddleocr) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\delll\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\delll\anaconda3\lib\site-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (2.27.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\delll\anaconda3\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\delll\anaconda3\lib\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: cohere in c:\users\delll\anaconda3\lib\site-packages (5.13.3)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (1.9.7)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (0.27.0)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (0.4.0)
# Requirement already satisfied: numpy<2.0,>=1.26 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (1.26.4)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (0.9.0)
# Requirement already satisfied: pydantic>=1.9.2 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (2.10.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (2.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (0.19.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (2.32.0.20241016)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\delll\anaconda3\lib\site-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere) (4.2.0)
# Requirement already satisfied: certifi in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere) (1.0.5)
# Requirement already satisfied: idna in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: sniffio in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\delll\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\delll\anaconda3\lib\site-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\delll\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\delll\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\delll\anaconda3\lib\site-packages (from tokenizers<1,>=0.15->cohere) (0.26.2)
# Requirement already satisfied: filelock in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.65.0)
# Requirement already satisfied: colorama in c:\users\delll\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (0.4.6)
# Requirement already satisfied: gradio in c:\users\delll\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.115.5)
# Requirement already satisfied: ffmpy in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.5.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (1.5.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.26.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in c:\users\delll\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (2.10.2)
# Requirement already satisfied: pydub in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart==0.0.12 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.8.0)
# Requirement already satisfied: safehttpx<1.0,>=0.1.1 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.1.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.13.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio) (0.32.1)
# Requirement already satisfied: fsspec in c:\users\delll\anaconda3\lib\site-packages (from gradio-client==1.5.0->gradio) (2023.10.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\delll\anaconda3\lib\site-packages (from gradio-client==1.5.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\delll\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\delll\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\delll\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\delll\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\delll\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\delll\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\delll\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\delll\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\delll\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\delll\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\delll\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\delll\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\delll\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\delll\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\delll\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\delll\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\delll\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\delll\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\delll\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: opencv-python-headless in c:\users\delll\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\delll\anaconda3\lib\site-packages (from opencv-python-headless) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\delll\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\delll\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\delll\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\delll\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\delll\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\delll\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\delll\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\delll\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from PIL import Image
from paddleocr import PaddleOCR
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import cohere
import re
import gradio as gr
import io

# %%
# Initialize PaddleOCR and Cohere API
paddle_ocr = PaddleOCR(use_angle_cls=True, lang='en')  # PaddleOCR for English with angle classification
co = cohere.Client("MstkmO4CEcoxvJuj8yZVtFIp4ApNf1mD5rQJe0yT")  # Replace with your actual Cohere API key
# Out:
# [2024/12/13 13:13:17] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\DELLL/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\DELLL/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='C:\\Users\\DELLL\\anaconda3\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\DELLL/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
# OCR and data extraction function
def process_documents(document_type, uploaded_files):
    extracted_data = []

    for uploaded_file in uploaded_files:
        # Load image
        image = Image.open(uploaded_file)
        image_cv2 = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)

        # OCR processing
        paddle_results = paddle_ocr.ocr(np.array(image))
        texts = [line[1][0] for line in paddle_results[0]]  # Extract text
        extracted_text = " ".join(texts)

        # Cohere API call
        prompt = f"Extract the following information from the text: {extracted_text}\n\n"
        if document_type == "Salary Slip":
            prompt += "Find and return the values for: Net Salary, Gross Salary, Basic Salary."
        elif document_type == "Profit and Loss Statement":
            prompt += "Find and return the values for: Total Revenue, Net Income."
        elif document_type == "Check":
            prompt += "Find and return the values for: Account Number, Amount (in Rupees), Bank Name."

        response = co.generate(model='command', prompt=prompt, max_tokens=200)
        result_text = response.generations[0].text.strip()

        # Parse the response for visualization
        temp_data = {}
        for line in result_text.split("\n"):
            if ":" in line:
                key, value = line.split(":", 1)
                temp_data[key.strip()] = value.strip()
        extracted_data.append(temp_data)

    return extracted_data

# %%
def visualize_results(document_type, uploaded_files, plot_type):
    extracted_data = process_documents(document_type, uploaded_files)

    if not extracted_data:
        return "No data extracted. Please check your input files.", None

    # Display extracted data in text format
    extracted_info = "\n".join([f"{key}: {value}" for data in extracted_data for key, value in data.items()])

    # Flatten extracted data for numeric values
    flattened_data = {}
    for data in extracted_data:
        for key, value in data.items():
            try:
                # Clean value and convert to float
                numeric_value = float(re.sub(r"[^\d.]+", "", value))
                flattened_data[key] = flattened_data.get(key, 0) + numeric_value
            except ValueError:
                pass

    if not flattened_data:
        return extracted_info, "No numeric data available for visualization."

    # Generate visualization
    labels = list(flattened_data.keys())
    values = list(flattened_data.values())

    # Create the plot
    fig, ax = plt.subplots(figsize=(8, 6))

    if plot_type == "Bar Plot":
        ax.bar(labels, values, color="skyblue", edgecolor="black")
        ax.set_title(f"{document_type} - Bar Plot")
        ax.set_ylabel("Amount")
        ax.set_xlabel("Fields")
        plt.xticks(rotation=45, ha="right")
    elif plot_type == "Pie Chart":
        ax.pie(values, labels=labels, autopct="%1.1f%%", startangle=140, colors=plt.cm.Paired.colors)
        ax.set_title(f"{document_type} - Pie Chart")

    # Save plot to a buffer
    buf = io.BytesIO()
    plt.tight_layout()
    plt.savefig(buf, format="png")
    
    # Convert the buffer to an image that Gradio can process
    buf.seek(0)
    image = Image.open(buf)

    return extracted_info, image

# %%
# Gradio Interface
with gr.Blocks() as demo:
    gr.Markdown("# Document OCR, Analysis, and Visualization")

    document_type = gr.Radio(
        ["Salary Slip", "Profit and Loss Statement", "Check"],
        label="Select Document Type",
    )
    uploaded_files = gr.File(file_types=["image"], file_count="multiple", label="Upload Document Images")
    plot_type = gr.Radio(["Bar Plot", "Pie Chart"], label="Select Plot Type")

    result = gr.Textbox(label="Extracted Information", lines=10, interactive=False)
    visualization_output = gr.Image(label="Visualization")

    submit_button = gr.Button("Process and Visualize")

    submit_button.click(
        visualize_results,
        inputs=[document_type, uploaded_files, plot_type],
        outputs=[result, visualization_output]
    )

# Launch Gradio Interface
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [2024/12/13 13:13:57] ppocr DEBUG: dt_boxes num : 41, elapsed : 1.42803955078125
# [2024/12/13 13:13:57] ppocr DEBUG: cls num  : 41, elapsed : 0.440380334854126
# [2024/12/13 13:14:03] ppocr DEBUG: rec_res num  : 41, elapsed : 6.015445947647095
